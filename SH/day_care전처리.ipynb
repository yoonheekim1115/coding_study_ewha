# %%
import pandas as pd

# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train=pd.read_csv("project/train_final.csv")

# %%
train.head(2)
# Out:
#    transaction_id  apartment_id   city dong jibun       apt  \
# 0               0          7622  서울특별시  신교동  6-13  신현(101동)
# 1               1          5399  서울특별시  필운동   142    사직파크맨션
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000

# %%
day_care=pd.read_csv("project2/day_care_final.csv")
day_care["gu"].unique()
# Out:
# array(['서대문구', '도봉구', '송파구', '성동구', '은평구', '서초구', '종로구', '영도구', '부산진구',
#        '양천구', '동작구', '부산중구', '서울강서구', '서구', '남구', '서울중구', '동래구', '강북구',
#        '금천구', '북구', '강동구', '영등포구', '해운대구', '기장군', '연제구', '중랑구', '구로구',
#        '수영구', '광진구', '부산강서구', '노원구', '관악구', '사하구', '사상구', '동구', '강남구',
#        '금정구'], dtype=object)

# %%
day_care.head(6)
#day_care.info()
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0  서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1  서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2  서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4  서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# 5  서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 0               5.0             1.0       7.0                    N
# 1               5.0             2.0      10.0                    N
# 2               6.0             1.0      32.0                    N
# 3               3.0             0.0       4.0                    N
# 4               7.0             2.0      10.0                    N
# ...

# %%
park=pd.read_csv("project/park.csv")
park.head(3)
# Out:
#     city  gu dong park_name park_type  park_area park_exercise_facility  \
# 0  부산광역시  남구  대연동      대연공원      근린공원    55227.0                    NaN
# 1  부산광역시  남구  대연동      당곡공원      역사공원    75465.0                    NaN
# 2  부산광역시  남구  대연동   대일어린이공원     어린이공원      422.1                    NaN
#
#   park_entertainment_facility park_benefit_facility park_cultural_facitiy  \
# 0                         NaN                   NaN                   NaN
# 1                         NaN                   NaN                   NaN
# 2                         NaN                   NaN                   NaN
#
#   park_facility_other  park_open_year reference_date
# 0                 NaN          1944.0     2018-08-14
# 1                 NaN          1944.0     2018-08-14
# 2                 NaN          1965.0     2018-08-14

# %%
sum(park.park_exercise_facility.isnull())
# Out:
# 1082

# %%
len(park["park_cultural_facitiy"])
park.park_type.unique()

#공원종류
#도시농업공원-도심속 텃밭가꾸기
# Out:
# array(['근린공원', '역사공원', '어린이공원', '묘지공원', '수변공원', '소공원', '문화공원', '체육공원',
#        '기타', '도시농업공원'], dtype=object)

# %%
day_care.head(10)
#day_care.info():7551개
#is_commuting_vehicle:496
#teacher_num:225
#nursing_room_num:3199  (아마제거??)
#playground:3925        (아마제거??)
#cctv:2271
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0  서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1  서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2  서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4  서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# 5  서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
# 6  서울특별시  서대문구        금화어린이집           국공립                 86         18.0
# 7  서울특별시  서대문구       꼬꼬마어린이집            가정                 20          7.0
# 8  서울특별시  서대문구      꼬마박사어린이집            가정                 19          6.0
# 9  서울특별시  서대문구       꼬마숲어린이집            가정                 20          7.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 0               5.0             1.0       7.0                    N
# ...

# %%
#drop시키기
day_care_drop=day_care.drop(["day_care_name","nursing_room_num","playground_num","CCTV_num","reference_date","city"],axis=1)

# %%
#day_care_drop['b/t_rate']=day_care_drop["day_care_baby_num"]/day_care_drop["teacher_num"]

# %%
day_care_drop.head(3)
# Out:
#      gu day_care_type  day_care_baby_num  teacher_num is_commuting_vehicle  \
# 0  서대문구           국공립                 70         11.0                    N
# 1  서대문구           국공립                 88         22.0                    N
# 2  서대문구            직장                 90         23.0                    N
#
#    b/t_rate
# 0  6.363636
# 1  4.000000
# 2  3.913043

# %%
day_care_drop[day_care_drop.teacher_num==0].count()
# Out:
# gu                      31
# day_care_type           31
# day_care_baby_num       31
# teacher_num             31
# is_commuting_vehicle    31
# dtype: int64

# %%
day_care_drop[day_care_drop.teacher_num.isnull()].count()
# Out:
# gu                      225
# day_care_type           225
# day_care_baby_num       225
# teacher_num               0
# is_commuting_vehicle      2
# dtype: int64

# %%
#day_care_drop.loc[day_care_drop.teacher_num.isnull().index,:]=0
day_care_drop.fillna({"teacher_num":0},inplace=True)
#day_care_drop[day_care_drop.teacher_num.isnull()]
#day_care_drop[day_care_drop.teacher_num.isnull()].teacher_num
#print(day_care_drop.teacher_num.mean())
#print(day_care_drop.teacher_num.median())

# %%
#day_care_drop[day_care_drop.teacher_num==0]
#day_care_drop[day_care_drop.teacher_num.isnull()].teacher_num

# %%
day_care_drop.gu.unique()
# Out:
# array(['서대문구', '도봉구', '송파구', '성동구', '은평구', '서초구', '종로구', '영도구', '부산진구',
#        '양천구', '동작구', '중구', '강서구', '서구', '남구', '동래구', '강북구', '금천구', '북구',
#        '강동구', '영등포구', '해운대구', '기장군', '연제구', '중랑구', '구로구', '수영구', '광진구',
#        '노원구', '관악구', '사하구', '사상구', '동구', '강남구', '금정구'], dtype=object)

# %%
day_care_drop[(day_care_drop.teacher_num!=0) & (day_care_drop.gu=='강남구')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, gu, day_care_type, day_care_baby_num, teacher_num, is_commuting_vehicle]
# Index: []

# %%
day_care_drop['gu'].unique()
# Out:
# array(['서대문구', '도봉구', '송파구', '성동구', '은평구', '서초구', '종로구', '영도구', '부산진구',
#        '양천구', '동작구', '부산중구', '서울강서구', '서구', '남구', '서울중구', '동래구', '강북구',
#        '금천구', '북구', '강동구', '영등포구', '해운대구', '기장군', '연제구', '중랑구', '구로구',
#        '수영구', '광진구', '부산강서구', '노원구', '관악구', '사하구', '사상구', '동구', '강남구',
#        '금정구'], dtype=object)

# %%
day_care_drop[(day_care_drop.teacher_num==0) & (day_care_drop.gu=='강남구')].teacher_num.index
# Out:
# Int64Index([7222, 7223, 7224, 7225, 7226, 7227, 7228, 7229, 7230, 7231,
#             ...
#             7435, 7436, 7437, 7438, 7439, 7440, 7441, 7442, 7443, 7444],
#            dtype='int64', length=223)

# %%
o=day_care_drop[day_care_drop.teacher_num!=0].groupby('gu').teacher_num.mean().round(0)
o['서초구']
# Out:
# 11.0

# %%
idx=day_care_drop[(day_care_drop.teacher_num==0) & (day_care_drop.gu=='강남구')].teacher_num.index
day_care_drop.loc[idx,'teacher_num']=11
#day_care_drop[(day_care_drop.teacher_num==0) & (day_care_drop.gu=='동래구')]

# %%
day_care_drop[(day_care_drop.teacher_num==0) & (day_care_drop.gu=='강남구')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, gu, day_care_type, day_care_baby_num, teacher_num, is_commuting_vehicle]
# Index: []

# %%
day_care_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7551 entries, 0 to 7550
# Data columns (total 6 columns):
# Unnamed: 0              7551 non-null int64
# gu                      7551 non-null object
# day_care_type           7551 non-null object
# day_care_baby_num       7551 non-null int64
# teacher_num             7551 non-null float64
# is_commuting_vehicle    7055 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 354.1+ KB

# %%
day_care_drop.to_csv('day_care_fill.csv')

# %%
day_care_drop
# Out:
#       Unnamed: 0    gu day_care_type  day_care_baby_num  teacher_num  \
# 0              0  서대문구           국공립                 70         11.0
# 1              1  서대문구           국공립                 88         22.0
# 2              2  서대문구            직장                 90         23.0
# 3              3  서대문구            가정                 18          5.0
# 4              4  서대문구           국공립                 93         20.0
# ...          ...   ...           ...                ...          ...
# 7546        7546   금정구            민간                 46         13.0
# 7547        7547   금정구            가정                 19          6.0
# 7548        7548   금정구            민간                 92         16.0
# 7549        7549   금정구            민간                 43         12.0
# 7550        7550   금정구            민간                 32          7.0
#
#      is_commuting_vehicle  col
# 0                       0    1
# 1                       0    1
# 2                       0    1
# ...

# %% [markdown]
# # vehicle

# %%
idx=day_care_drop[day_care_drop['is_commuting_vehicle']=='N'].is_commuting_vehicle.index
day_care_drop.loc[idx,'is_commuting_vehicle']=0
idx2=day_care_drop[day_care_drop['is_commuting_vehicle']=='y'].is_commuting_vehicle.index
day_care_drop.loc[idx2,'is_commuting_vehicle']=1
day_care_drop.groupby(['gu','is_commuting_vehicle']).count()
day_care_drop['col']=1
a=pd.DataFrame(day_care_drop.groupby(['gu',"is_commuting_vehicle"]).count())
a
b=pd.DataFrame(day_care_drop.groupby(['gu']).count())
b['col']
#a['col2']=b['col']
a.head()
# Out:
#                           Unnamed: 0  day_care_type  day_care_baby_num  \
# gu  is_commuting_vehicle
# 강북구                              167            167                167
# 관악구 0                            195            195                195
#     1                             76             76                 76
# 광진구 0                            158            158                158
#     1                             39             39                 39
#
#                           teacher_num  col
# gu  is_commuting_vehicle
# 강북구                               167  167
# 관악구 0                             195  195
#     1                              76   76
# 광진구 0                             158  158
#     1                              39   39

# %%
c=a.reset_index()
#b[b.gu=='강북구]
c
# Out:
#       gu is_commuting_vehicle  Unnamed: 0  day_care_type  day_care_baby_num  \
# 0    강북구                              167            167                167
# 1    관악구                    0         195            195                195
# 2    관악구                    1          76             76                 76
# 3    광진구                    0         158            158                158
# 4    광진구                    1          39             39                 39
# ..   ...                  ...         ...            ...                ...
# 63   종로구                    1          14             14                 14
# 64   중랑구                    0         144            144                144
# 65   중랑구                    1          98             98                 98
# 66  해운대구                    0          80             80                 80
# 67  해운대구                    1         143            143                143
#
#     teacher_num  col
# 0           167  167
# ...

# %%
day_care_drop[day_care_drop.gu=='중랑구'].count()
# Out:
# Unnamed: 0              242
# gu                      242
# day_care_type           242
# day_care_baby_num       242
# teacher_num             242
# is_commuting_vehicle    242
# col                     242
# dtype: int64

# %%
day_care_drop[day_care_drop.gu=='중랑구'].count()
day_care_drop[day_care_drop.gu=='강동구']
# Out:
#       Unnamed: 0    gu day_care_type  day_care_baby_num  teacher_num  \
# 0              0  서대문구           국공립                 70         11.0
# 1              1  서대문구           국공립                 88         22.0
# 2              2  서대문구            직장                 90         23.0
# 3              3  서대문구            가정                 18          5.0
# 4              4  서대문구           국공립                 93         20.0
# ...          ...   ...           ...                ...          ...
# 7546        7546   금정구            민간                 46         13.0
# 7547        7547   금정구            가정                 19          6.0
# 7548        7548   금정구            민간                 92         16.0
# 7549        7549   금정구            민간                 43         12.0
# 7550        7550   금정구            민간                 32          7.0
#
#      is_commuting_vehicle  col
# 0                       0    1
# 1                       0    1
# 2                       0    1
# ...

# %%
b[["col"]].head()
# Out:
#      col
# gu
# 강남구  223
# 강동구  272
# 강북구  167
# 관악구  271
# 광진구  197

# %%
a=pd.DataFrame(day_care_drop.groupby(['gu',"is_commuting_vehicle"]).count())
b=pd.DataFrame(day_care_drop.groupby(['gu']).count())

pd.merge(a,b[["col"]], how="left",left_index=True, right_index=True)
day_care_drop[day_care_drop.is_commuting_vehicle.isnull()].gu.unique()
# Out:
# array(['강동구', '사상구', '강남구'], dtype=object)

# %%
# Out:
#                            Unnamed: 0  day_care_type  day_care_baby_num  \
# gu   is_commuting_vehicle
# 강북구                               167            167                167
# 관악구  0                            195            195                195
#      1                             76             76                 76
# 광진구  0                            158            158                158
#      1                             39             39                 39
# ...                               ...            ...                ...
# 종로구  1                             14             14                 14
# 중랑구  0                            144            144                144
#      1                             98             98                 98
# 해운대구 0                             80             80                 80
#      1                            143            143                143
#
#                            teacher_num  col
# gu   is_commuting_vehicle
# ...

# %%
alist=[]
for i in range(34):
    for j in range(2):
        alist.append(a.index[i][j])

# %%
alist
# Out:
# ['강북구',
#  ' ',
#  '관악구',
#  0,
#  '관악구',
#  1,
#  '광진구',
#  0,
#  '광진구',
#  1,
#  '구로구',
#  0,
#  '구로구',
#  1,
#  '금정구',
#  1,
#  '금정구',
#  'n',
#  '금천구',
#  0,
#  '금천구',
#  1,
#  '기장군',
#  0,
#  '기장군',
#  1,
#  '남구',
#  0,
#  '남구',
#  1,
#  '노원구',
#  0,
#  '노원구',
#  1,
#  '도봉구',
#  0,
#  '도봉구',
#  1,
#  '동구',
#  0,
#  '동구',
#  1,
#  '동래구',
#  0,
#  '동래구',
#  1,
#  '동작구',
#  ' ',
#  '부산강서구',
#  0,
#  '부산강서구',
#  1,
#  '부산중구',
#  0,
#  '부산중구',
#  1,
#  '부산진구',
#  0,
#  '부산진구',
#  1,
#  '북구',
#  0,
#  '북구',
#  1,
#  '사상구',
#  0,
#  '사상구',
#  1]

# %%
gulist=['서대문구', '도봉구', '송파구', '성동구', '은평구', '서초구', '종로구', '영도구', '부산진구',
       '양천구', '동작구', '중구', '강서구', '서구', '남구', '동래구', '강북구', '금천구', '북구',
       '강동구', '영등포구', '해운대구', '기장군', '연제구', '중랑구', '구로구', '수영구', '광진구',
       '노원구', '관악구', '사하구', '사상구', '동구', '강남구', '금정구']

# %%
for i in day_care_drop[(day_care_drop.teacher_num==0) & (day_care_drop.gu==gulist)]:
    day_care_drop[day_care_drop.teacher_num=day_care_drop[day_care_drop.teacher_num!=0].groupby('gu').teacher_num.mean().round(0)[i]
# Out:
# Empty DataFrame
# Columns: [gu, day_care_type, day_care_baby_num, teacher_num, is_commuting_vehicle, b/t_rate]
# Index: []

# %%
day_care_drop[day_care_drop.teacher_num]
# Out:
# Empty DataFrame
# Columns: [gu, day_care_type, day_care_baby_num, teacher_num, is_commuting_vehicle, b/t_rate]
# Index: []

# %%
day_care_drop['b/t_rate']=day_care_drop["day_care_baby_num"]/day_care_drop["teacher_num"]
day_care_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7551 entries, 0 to 7550
# Data columns (total 6 columns):
# gu                      7551 non-null object
# day_care_type           7551 non-null object
# day_care_baby_num       7551 non-null int64
# teacher_num             7326 non-null float64
# is_commuting_vehicle    7055 non-null object
# b/t_rate                7326 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 354.1+ KB

# %%
day_care_drop[day_care_drop.teacher_num.isnull()]
# Out:
#        gu day_care_type  day_care_baby_num  teacher_num is_commuting_vehicle  \
# 6417  노원구           국공립                 31          NaN                    N
# 6538  노원구           국공립                 38          NaN                    N
# 7222  강남구            직장                 49          NaN                  NaN
# 7223  강남구            직장                 60          NaN                  NaN
# 7224  강남구            직장                 61          NaN                  NaN
# ...   ...           ...                ...          ...                  ...
# 7440  강남구            가정                 20          NaN                  NaN
# 7441  강남구            민간                 37          NaN                  NaN
# 7442  강남구            가정                 19          NaN                  NaN
# 7443  강남구           국공립                 92          NaN                  NaN
# 7444  강남구            협동                 69          NaN                  NaN
#
#       b/t_rate
# 6417       NaN
# ...

# %%
b=pd.melt(day_care_drop, id_vars=["gu","day_care_type"])
b.head(3)
# Out:
#      gu day_care_type           variable value
# 0  서대문구           국공립  day_care_baby_num    70
# 1  서대문구           국공립  day_care_baby_num    88
# 2  서대문구            직장  day_care_baby_num    90

# %%
pd.pivot_table(day_care_drop,index=['gu','day_care_type'],aggfunc=np.sum)
# Out:
#                       b/t_rate  day_care_baby_num  teacher_num
# gu   day_care_type
# 강남구  가정               0.000000               1273          0.0
#      국공립              0.000000               4666          0.0
#      민간               0.000000               3787          0.0
#      직장               0.000000               1810          0.0
#      협동               0.000000                 69          0.0
# ...                        ...                ...          ...
# 해운대구 민간             695.418849               5767        985.0
#      법인·단체           10.950000                101         18.0
#      사회복지법인          90.119986               1273        187.0
#      직장              29.021581                281         58.0
#      협동               4.750000                 19          4.0
#
# [220 rows x 3 columns]

# %%
c=pd.DataFrame(day_care_drop.groupby(['gu','day_care_type']).day_care_type.count())
c
pd.pivot_table(c,index='gu',columns='day_care_type',values=['b/t_rate','day_care_baby_num','teacher_num'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-6df87f47c275> in <module>
#       1 c=pd.DataFrame(day_care_drop.groupby(['gu','day_care_type']).day_care_type.count())
#       2 c
# ----> 3 pd.pivot_table(c,index='gu',columns='day_care_type',values=['b/t_rate','day_care_baby_num','teacher_num'])
#
# C:\Users\a0104\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      70         for i in values:
#      71             if i not in data:
# ---> 72                 raise KeyError(i)
#      73
#      74         to_filter = []
#
# KeyError: 'b/t_rate'

# %%
pd.pivot_table(day_care_drop, columns=['gu','day_care_type'] values=[day_care_baby_num	"teacher_num","is_commuting_vehicle","b/t_rate"])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-67-ddd003724f15> in <module>
# ----> 1 pd.pivot_table(day_care_drop, columns='gu', values='day_care_type')
#
# C:\Users\a0104\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      94
#      95     grouped = data.groupby(keys, observed=observed)
# ---> 96     agged = grouped.agg(aggfunc)
#      97     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#      98         agged = agged.dropna(how="all")
#
# C:\Users\a0104\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, arg, *args, **kwargs)
#    1453     @Appender(_shared_docs["aggregate"])
#    1454     def aggregate(self, arg=None, *args, **kwargs):
# ...

# %%
day_care_drop.columns
# Out:
# Index(['gu', 'day_care_type', 'day_care_baby_num', 'teacher_num',
#        'is_commuting_vehicle', 'b/t_rate'],
#       dtype='object')

# %%
sum(day_care.reference_date.isnull())
# Out:
# 0

# %%
day_care.day_care_type.unique()
# Out:
# array(['국공립', '직장', '가정', '민간', '법인·단체', '협동', '사회복지법인'], dtype=object)

# %%
train_final=pd.read_csv("project2/train_final.csv")
train_final.head(5)
# Out:
#    Unnamed: 0  transaction_id  apartment_id   city dong jibun       apt  \
# 0           0               0          7622  서울특별시  신교동  6-13  신현(101동)
# 1           1              98          7623  서울특별시  신교동  6-11  신현(102동)
# 2           2             511          7622  서울특별시  신교동  6-13  신현(101동)
# 3           3             840          7623  서울특별시  신교동  6-11  신현(102동)
# 4           4            1201          7623  서울특별시  신교동  6-11  신현(102동)
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1  신교동 6-11 신현(102동)               84.82                2002
# 2  신교동 6-13 신현(101동)               84.82                2002
# 3  신교동 6-11 신현(102동)               81.02                2002
# 4  신교동 6-11 신현(102동)               84.82                2002
#
#    transaction_year_month transaction_date  floor  transaction_real_price   gu
# 0                  200801            21~31      2                   37500  종로구
# ...

# %%
train=pd.read_csv("project2/train_final.csv")
day_care=pd.read_csv("project2/day_care_final.csv")
park= pd.read_csv("project2/park_final.csv")

# %%
#nursing room, playground 제거
ㅇ

# %%
train.head()
# Out:
#    Unnamed: 0  transaction_id  apartment_id   city dong jibun       apt  \
# 0           0               0          7622  서울특별시  신교동  6-13  신현(101동)
# 1           1              98          7623  서울특별시  신교동  6-11  신현(102동)
# 2           2             511          7622  서울특별시  신교동  6-13  신현(101동)
# 3           3             840          7623  서울특별시  신교동  6-11  신현(102동)
# 4           4            1201          7623  서울특별시  신교동  6-11  신현(102동)
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1  신교동 6-11 신현(102동)               84.82                2002
# 2  신교동 6-13 신현(101동)               84.82                2002
# 3  신교동 6-11 신현(102동)               81.02                2002
# 4  신교동 6-11 신현(102동)               84.82                2002
#
#    transaction_year_month transaction_date  floor  transaction_real_price   gu
# 0                  200801            21~31      2                   37500  종로구
# ...

# %%
park.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   city  gu dong park_name park_type  park_area  \
# 0           0             0  부산광역시  남구  대연동      대연공원      근린공원    55227.0
# 1           1             1  부산광역시  남구  대연동      당곡공원      역사공원    75465.0
# 2           2             2  부산광역시  남구  대연동   대일어린이공원     어린이공원      422.1
# 3           3             3  부산광역시  남구  대연동   못골어린이공원     어린이공원      499.8
# 4           4             4  부산광역시  남구  용호동   솔밭어린이공원     어린이공원     1500.2
#
#   park_exercise_facility park_entertainment_facility park_benefit_facility  \
# 0                    NaN                         NaN                   NaN
# 1                    NaN                         NaN                   NaN
# 2                    NaN                         NaN                   NaN
# 3                    NaN                         NaN                   NaN
# 4                    NaN                         NaN                   NaN
#
# ...

# %%
day_care_drop()
