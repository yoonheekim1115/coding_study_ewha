# %% [markdown]
# # 그리디 개념

# %% [markdown]
# ##### 그리디 알고리즘: 현재 상황에서 지금 당장 좋은 것만 고르는 탐욕적 문제 해결방법.
# * 현재의 선택이 나중에 미칠 영향에 대해서는 고려하지 않는다.
# * '가장 큰 순서대로', '가장 작은 순서대로'와 같은 기준을 제시해준다.
# * 대체로 정렬 알고리즘을 사용했을 때 만족시킬 수 있으므로 자주 정렬 알고리즘과 짝을 이뤄 출제된다.

# %% [markdown]
# #### 예제

# %%
# 3-1 거스름돈 : 500, 100, 50, 10

n=1260
count=0 # 거슬러 줘야할 동전의 최소 개수 구하기

# 큰 단위의 화폐부터 차례대로 확인
coin_types = [500,100,50,10]

for coin in coin_types:
    count+=n // coin # 몫: 해당화페로 거슬러 줄 수 있는 동전개수 세기
    n%=coin # 나머지: 이전 화폐로 거슬러 주고 남은 금액
    
print(count) # 6개
# Out:
# 6

# %%
# 3-2 큰 수의 법칙
# 책풀이

# N, M, K를 공백으로 구분해 입력받기
n, m, k = map(int, input().split()) # 배열의 크기, 숫자가 더해지는 횟수, 연속해서 더해질 수 있는 횟수

# N개의 수를 공백으로 구분하여 입력받기
data = list(map(int, input().split())) # 2 4 5 4 6

data.sort() # 입력받은 수 정렬
first = data[n-1] # 가장 큰 수
second= data[n-2] # 두번째로 큰 수

# 가장 큰 수가 더해지는 횟수 계산
count = int(m/(k+1)) * k # 수열의 반복횟수 * 가장 큰 수의 연속횟수
count += m % (k+1) # 나머지가 0이 아닌 경우 가장 큰 수 또 더함 예) m=9, 9 % (3+1) = 1 -> 가장큰수인 6을 한번 더 더함

result = 0
result += (count) * first # 가장 큰 수 더하기
result += (m - count) * second # 두번째로 큰 수 더하기

print(result) # 46
# Out:
# 5 8 3
# 2 4 5 4 6
# 46

# %%
# 3-2 큰 수의 법칙
# 내풀이
n, m, k = map(int, input().split()) # 배열의 크기, 숫자가 더해지는 횟수, 연속해서 더해질 수 있는 횟수
data = list(map(int, input().split())) # 2 4 5 4 6

data.sort(reverse=True)
first = data[0] # 가장 큰 수
second = data[1] # 두번째로 큰 수

result = 0

while m!=0:
    for i in range(k):
        result += first    
        m -= 1
    
    result += second
    m -= 1
    
print(result)
# Out:
# 5 8 3
# 2 4 5 4 6
# 46

# %%
# 3-3 숫자카드 게임
# 책풀이 - min함수 이용

# N,M을 공백으로 구분해서 입력받기
n,m = map(int,input().split())

result=0
# 한 줄씩 입력받아 확인
for i in range(n):
    data = list(map(int, input().split()))
    # 현재 줄에서 가장 작은 수 찾기
    min_value = min(data)
    # 가장 작은 수들 중에서 가장 큰 수 찾기
    result = max(result, min_value)
    
print(result)
# Out:
# 2 4
# 7 3 1 8
# 3 3 3 4
# 3

# %%
# 책풀이2 - 2중 반복문 구조 이용

# N,M을 공백으로 구분해서 입력받기
n,m = map(int,input().split())

result=0
# 한 줄씩 입력받아 확인
for i in range(n):
    data = list(map(int, input().split()))
    # 현재 줄에서 가장 작은 수 찾기
    min_value = 10001
    for a in data:
        min_value = min(min_value, a)
    # 가장 작은 수들 중에서 가장 큰 수 찾기
    result = max(result,min_value)

print(data)
print(result)
# Out:
# 2 4
# 7 3 1 8
# 3 3 3 4
# [3, 3, 3, 4]
# 3

# %%
type(result)
# Out:
# int

# %%
# 2중 반복문 변형시도

# N,M을 공백으로 구분해서 입력받기
n,m = map(int,input().split())

#result=0
# 한 줄씩 입력받아 확인
for i in range(n):
    data = list(map(int, input().split()))
    min_value = min(data)
    # 가장 작은 수들 중에서 가장 큰 수 찾기
    #result = max(result, min_value)
    
print(max(min_value)) # int 타입은 반복 돌릴 수 없음(min_value), 단일 객체가 아닌 여러개의 요소를 가진 객체(리스트, 튜플, 딕셔너리, range() 함수등) 필요
# Out:
# 2 4
# 7 3 1 8
# 3 3 3 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-fa90883a0443> in <module>
#      11     #result = max(min_value)
#      12
# ---> 13 print(max(min_value))
#
# TypeError: 'int' object is not iterable

# %%
# 3-5 1이 될때까지 - N을 1로 만드는 최소횟수 구하기
# K로 나누거나 1 빼거나
# 책풀이
n, k = map(int, input().split())
result=0

# N이 K 이상이라면 K 로 계속 나누기
while n >= k:
    # N이 K로 나누어 떨어지지 않는다면 N에서 1씩 빼기
    while n % k != 0:
        n -= 1
        result += 1 # 횟수 세기
    
    # K로 나누기
    n //= k
    result += 1 # 횟수 세기

# 마지막으로 남은 수에 대하여 1씩 빼기
while n > 1:
    n -= 1
    result += 1
    
print(result)
# Out:
# 25 5
# 2

# %%
# 책풀이2
n, k = map(int, input().split())
result=0

while True:
    # N == K로 나누어 떨어지는 수가 될때까지 1씩 빼기
    target == (n // k) * k
    result += (n - target)
    n = target
    # N이 K보다 작을 때(더이상 나눌 수 없을 때) 반복문 탈출
    if n < k:
        break
    # K로 나누기
    result += 1
    n //= k

# 마지막으로 남은 수에 대하여 1씩 빼기
result += (n-1)
print(result)

# %% [markdown]
# # 실전문제 1. 모험가 길드

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 풀이
# 현재 그룹에 포함된 모험가의 수 >= 현재 확인하고 있는 공포도 --> 그룹으로 설정
# 그룹수의 최댓값 구해야 하니까 최소한의 모험가 수만 포함해 그룹 결성하기

n = int(input())
data = list(map(int, input().split()))
data.sort()

result = 0 # 총 그룹의 수
count = 0 # 현재 그룹에 포함된 모험가의 수

for i in data: # 공포도를 낮은 것부터 하나씩 확인 1 2 2 2 3
    count += 1 # 현재 그룹에 해당 모험가를 포함시키기
    if count >= i: # 현재 그룹에 포함된 모험가의 수가 현재의 공포도 이상이라면, 그룹 결성
        result += 1 # 총 그룹의 수 증가시키기
        count = 0 # 현재 그룹에 포함된 모험가의 수 초기화

print(result) # 총 그룹의 수 출력
# Out:
# 5
# 2 3 1 2 2
# 2

# %% [markdown]
# ### 풀이 이해해보기.....
# ##### 1 2 2 2 3
#
# i = 1<br>
# count = 1<br>
# count = i<br>
# result = 1<br>
# 1그룹 인원:1명<br>
#
# i = 2<br>
# count = 1<br>
# count < i --> 다시 위로 돌아가<br>
# i = 2<br>
# count = 2<br>
# count = i<br>
# result = 2<br>
# 2그룹 인원:2명<br>
#
# i = 2<br>
# count = 1<br>
# count < i --> 다시 위로 돌아가<br>
# i = 3<br>
# count = 2<br>
# count < i<br>
# 그룹 못되고 끝남
# #### 결론: 최대 2개의 그룹 생성가능<br>

# %% [markdown]
# # 실전문제 2. 곱하기 혹은 더하기

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 풀이
data = input()

# 첫 번째 문자를 숫자로 변경하여 대입
result = int(data[0])

for i in range(1, len(data)):
    # 두 수 중에서 하나라도 '0' 혹은 '1'인 경우, 곱하기보다는 더하기 수행, 2 이상이면 곱하기 수행
    num = int(data[i])
    if num <= 1 or result <= 1:
        result += num
    else:
        result *= num

print(result)
# Out:
# 567
# 210

# %%
# data, result, num 다 str이므로 int 붙여줘야함
data = input()

# 첫 번째 문자를 숫자로 변경하여 대입
#result = int(data[0])
result = data[0]

for i in range(1, len(data)):
    # 두 수 중에서 하나라도 '0' 혹은 '1'인 경우, 곱하기보다는 더하기 수행, 2 이상이면 곱하기 수행
    num = data[i]
    if num <= 1 or result <= 1:
        result += num
    else:
        result *= num

print(result)
# Out:
# 567
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-dd4e4bfcc2fc> in <module>
#       9     # 두 수 중에서 하나라도 '0' 혹은 '1'인 경우, 곱하기보다는 더하기 수행, 2 이상이면 곱하기 수행
#      10     num = data[i]
# ---> 11     if num <= 1 or result <= 1:
#      12         result += num
#      13     else:
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
data = input()

type(data)
# Out:
# 567
# str

# %%
type(result)
# Out:
# str

# %%
type(num)
# Out:
# str

# %% [markdown]
# # 실전문제 3. 문자열 뒤집기

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 풀이
# 전부 0으로 바꾸는거, 전부 1로 바꾸는 거 중에 더 적은 횟수 가지는걸로 최소횟수 계산

data = input()
count0 = 0 # 전부 0으로 바꾸는 경우
count1 = 0 # 전부 1로 바꾸는 경우

# 첫 번째 원소에 대해서 처리
if data[0] == '1':
    count0 += 1
else:
    count1 += 1

# 두 번째 원소부터 모든 원소를 확인하며
for i in range(len(data) - 1): # 인덱싱 때문에 -1, range(0,len(data)-1)
    if data[i] != data[i + 1]:
        # 다음 수에서 1로 바뀌는 경우
        if data[i + 1] == '1':
            count0 += 1
        # 다음 수에서 0으로 바뀌는 경우
        else:
            count1 += 1

print(min(count0, count1)) #0으로 바꾸는게 더 효율적
# Out:
# 0001100
# 1

# %%
# 풀이

# 첫번째 원소 처리 빼도 나옴
data = input()
count0 = 0 # 전부 0으로 바꾸는 경우
count1 = 0 # 전부 1로 바꾸는 경우

# 두 번째 원소부터 모든 원소를 확인하며
for i in range(len(data)-1): # i+1 때문에 -1, range(0,len(data)-1)
    if data[i] != data[i + 1]:
        # 다음 수에서 1로 바뀌는 경우
        if data[i + 1] == '1':
            count0 += 1
        # 다음 수에서 0으로 바뀌는 경우
        else:
            count1 += 1

print(min(count0, count1)) #0으로 바꾸는게 더 효율적
# Out:
# 0001100
# 1

# %% [markdown]
# # 실전문제 4. 만들 수 없는 금액

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 풀이
# 오름차순 정렬 -> 1부터 차례대로 특정 금액 만들 수 있는지 확인 -> 1부터 tagret-1까지 만들 수 있음
# 화폐단위 3,2,1,1,9

n = int(input())
data = list(map(int, input().split()))
data.sort() # 1,1,2,3,9

target = 1
for x in data:
    # 만들 수 없는 금액을 찾았을 때 반복 종료
    if target < x:
        break
    target += x

# 만들 수 없는 금액 출력
print(target)
# Out:
# 5
# 2 1 3 3 8
# 18

# %%
# 나만의 풀이

# %% [markdown]
# # 실전문제 5. 볼링공 고르기

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 풀이 - 서로 다른 무게의 볼링공 고르는 경우의 수 출력

n, m = map(int, input().split()) # 볼링공 개수, 공의 최대 무게
data = list(map(int, input().split()))

# 1부터 10까지의 무게가 인덱스인 리스트
array = [0] * 11

for x in data:
    # 각 무게에 해당하는 볼링공의 개수 카운트
    array[x] += 1

result = 0
# 1부터 m까지(최대무게)의 각 무게에 대하여 처리
for i in range(1, m + 1):
    n -= array[i] # 무게가 i인 볼링공의 개수(A가 선택할 수 있는 개수) 제외
    result += array[i] * n # B가 선택하는 경우의 수와 곱해주기

print(result)
# Out:
# 5 3
# 1 3 2 3 2
# 8

# %% [markdown]
# # 실전문제 6. 무지의 먹방 라이브

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="450"/>
# </div>

# %%
# 프로그래머스에 주어진 기본코드
#include <string>
#include <vector>

using namespace std;

int solution(vector<int> food_times, long long k) {
    int answer = 0;
    return answer;
}

# %%
# 풀이...모르게써여.....
  
import heapq

def solution(food_times, k):
    # 전체 음식을 먹는 시간보다 k가 크거나 같다면 -1
    if sum(food_times) <= k:
        return -1

    # 시간이 작은 음식부터 빼야 하므로 우선순위 큐를 이용
    q = []
    for i in range(len(food_times)):
        # (음식 시간, 음식 번호) 형태로 우선순위 큐에 삽입
        heapq.heappush(q, (food_times[i], i + 1))  

    sum_value = 0 # 먹기 위해 사용한 시간
    previous = 0 # 직전에 다 먹은 음식 시간
    length = len(food_times) # 남은 음식의 개수

    # sum_value + (현재의 음식 시간 - 이전 음식 시간) * 현재 음식 개수와 k 비교
    while sum_value + ((q[0][0] - previous) * length) <= k:
        now = heapq.heappop(q)[0]
        sum_value += (now - previous) * length
        length -= 1 # 다 먹은 음식 제외
        previous = now # 이전 음식 시간 재설정

    # 남은 음식 중에서 몇 번째 음식인지 확인하여 출력
    result = sorted(q, key=lambda x: x[1]) # 음식의 번호 기준으로 정렬
    return result[(k - sum_value) % length][1]
